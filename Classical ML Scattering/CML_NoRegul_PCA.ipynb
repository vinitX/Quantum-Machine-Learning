# %% [markdown]
# # Dense Neural Network
#
# * Here we are dealing with the most basic neural network.
# The network contains two hidden Dense Neural Networks.
#
# * We use Standard Scaling for input(X) and Mean-Max Scaling for output(Y). Tanh is used as the output activation function.
#
# * 12th label parameter (one of the Dihedral angles) had some issues which is fixed.
#
# * IQR method is used to remove outliers.
#
#
# # Data Augmentation using FFT
# I was experimenting with the data by taking its fourier transform to see if it captures the labels better than its original counterpart.

# %%
import numpy as np # linear algebra
from scipy import signal
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import time
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPool1D, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X = np.load('/content/drive/My Drive/Quantum Research/QML Scattering/Input_data_ML.npy')
Y = np.load('/content/drive/My Drive/Quantum Research/QML Scattering/Output_data_ML.npy')

X=X.astype(np.float64)
Y=Y.astype(np.float64)

print(np.shape(X),np.shape(Y))
X.dtype, Y.dtype
# Out:
# (1070107, 38) (15, 1070107)
# (dtype('float64'), dtype('float64'))

# %% [markdown]
# * I have applied a PCA to the scattering data to remove those components that do not make a difference. (Didn't like the idea)
# * I have applied a log on the degrees of freedom to reduce the skewness in the data
# * Float32 to Float64
# * I have removed some of the points using the IQR method. (Done)
# * I have removed the negative values of the dihedral angles and multiply the bond distances by 10 to get numbers in the same orders as the bonds/dihedrals
# * I have taken 900K data points to train and I have applied
# a standard scaler over them. (Done)

# %%
pca=PCA(n_components=20)
X=pca.fit_transform(X)

scaler2 =StandardScaler()
X=scaler2.fit_transform(X)

# %%
Y=Y.T
Y[:,6:]=Y[:,6:]%(2*np.pi)

y_mean=np.mean(Y,axis=0)
y_std=np.std(Y,axis=0)
Y=(Y-y_mean)/y_std

#Y=np.log(Y)

R=np.array([i for i in range(Y.shape[0])])
np.random.shuffle(R)
X=X[R,:]
Y=Y[R,:]  

Q1=np.quantile(Y,0.10,axis=0)
Q3=np.quantile(Y,0.90,axis=0)
IQR=Q3-Q1
X=X[~((Y < (Q1 - 1.5 * IQR)) |(Y > (Q3 + 1.5 * IQR))).any(axis=1)]
Y=Y[~((Y < (Q1 - 1.5 * IQR)) |(Y > (Q3 + 1.5 * IQR))).any(axis=1)]

xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2)
print(np.shape(xtrain),np.shape(ytrain),np.shape(xtest),np.shape(ytest))

'''
#Re-Normalization is the worst idea. 
print(np.mean(Y,axis=0),np.std(Y,axis=0))
y_mean=np.mean(Y,axis=0)
y_std=np.std(Y,axis=0)
Y=(Y-y_mean)/y_std
'''
print(np.mean(Y,axis=0),np.std(Y,axis=0))
# Out:
# (818880, 20) (818880, 15) (204720, 20) (204720, 15)
# [ 0.00367391  0.00301703  0.00192874  0.00272646  0.00344894  0.00312251
#  -0.02518176  0.01479297 -0.0200592  -0.02218453 -0.00711926  0.00922037
#   0.15577354 -0.14126018  0.10889032] [0.21967639 0.22145078 0.23628999 0.21217199 0.21382921 0.18725208
#  0.99315809 0.98468965 0.99251663 0.99288506 0.99478313 1.00079107
#  0.29176488 0.29879649 0.27264246]

# %%
plt.plot(X[10000,:])
plt.show()
for i in range(6):
    plt.hist(Y[:,i],bins=50)
plt.show()
for i in range(6,11):
    plt.hist(Y[:,i],bins=50)
plt.show()
for i in range(11,15):
    plt.hist(Y[:,i],bins=50)
plt.show()

# %%
model = Sequential()

model.add(Dense(475, activation='relu', input_shape=(20,)))
#model.add(LeakyReLU(alpha=.1))
#model.add(BatchNormalization())
#model.add(Dropout(0.25))

model.add(Dense(475, activation='relu'))
#model.add(LeakyReLU(alpha=.1))
#model.add(BatchNormalization())
#model.add(Dropout(0.25))

model.add(Dense(475, activation='relu'))
#model.add(LeakyReLU(alpha=.1))
#model.add(BatchNormalization())
#model.add(Dropout(0.25))

model.add(Dense(15, activation='linear')) #tanh

# %%
model.compile(loss='mse', optimizer = Adam(lr=1e-4), metrics=["accuracy"])
annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 475)               9975
# _________________________________________________________________
# dense_2 (Dense)              (None, 475)               226100
# _________________________________________________________________
# dense_3 (Dense)              (None, 475)               226100
# _________________________________________________________________
# dense_4 (Dense)              (None, 15)                7140
# =================================================================
# Total params: 469,315
# Trainable params: 469,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x=xtrain, y=ytrain, batch_size=512,
                epochs=50, 
                verbose=1,  #1 for ETA, 0 for silent
                validation_data=(xtest, ytest), 
                callbacks=[annealer])
# Out:
# Train on 818880 samples, validate on 204720 samples
# Epoch 1/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.1168 - accuracy: 0.6200 - val_loss: 0.0832 - val_accuracy: 0.6803
# Epoch 2/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0626 - accuracy: 0.7246 - val_loss: 0.0494 - val_accuracy: 0.7555
# Epoch 3/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0411 - accuracy: 0.7772 - val_loss: 0.0370 - val_accuracy: 0.7926
# Epoch 4/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0308 - accuracy: 0.8077 - val_loss: 0.0276 - val_accuracy: 0.8209
# Epoch 5/50
# 818880/818880 [==============================] - 50s 62us/step - loss: 0.0249 - accuracy: 0.8278 - val_loss: 0.0241 - val_accuracy: 0.8307
# Epoch 6/50
# 818880/818880 [==============================] - 50s 62us/step - loss: 0.0211 - accuracy: 0.8417 - val_loss: 0.0205 - val_accuracy: 0.8476
# Epoch 7/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0185 - accuracy: 0.8523 - val_loss: 0.0186 - val_accuracy: 0.8526
# Epoch 8/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0163 - accuracy: 0.8619 - val_loss: 0.0163 - val_accuracy: 0.8637
# Epoch 9/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0148 - accuracy: 0.8687 - val_loss: 0.0153 - val_accuracy: 0.8669
# Epoch 10/50
# 818880/818880 [==============================] - 54s 66us/step - loss: 0.0135 - accuracy: 0.8745 - val_loss: 0.0133 - val_accuracy: 0.8775
# Epoch 11/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0125 - accuracy: 0.8804 - val_loss: 0.0127 - val_accuracy: 0.8797
# Epoch 12/50
# 818880/818880 [==============================] - 50s 62us/step - loss: 0.0116 - accuracy: 0.8844 - val_loss: 0.0119 - val_accuracy: 0.8833
# Epoch 13/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0109 - accuracy: 0.8892 - val_loss: 0.0112 - val_accuracy: 0.8898
# Epoch 14/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0102 - accuracy: 0.8922 - val_loss: 0.0106 - val_accuracy: 0.8910
# Epoch 15/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0096 - accuracy: 0.8955 - val_loss: 0.0101 - val_accuracy: 0.8938
# Epoch 16/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0092 - accuracy: 0.8986 - val_loss: 0.0096 - val_accuracy: 0.8974
# Epoch 17/50
# 818880/818880 [==============================] - 51s 63us/step - loss: 0.0087 - accuracy: 0.9011 - val_loss: 0.0093 - val_accuracy: 0.8998
# Epoch 18/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0083 - accuracy: 0.9034 - val_loss: 0.0088 - val_accuracy: 0.9012
# Epoch 19/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0080 - accuracy: 0.9057 - val_loss: 0.0084 - val_accuracy: 0.9046
# Epoch 20/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0077 - accuracy: 0.9079 - val_loss: 0.0082 - val_accuracy: 0.9054
# Epoch 21/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0074 - accuracy: 0.9093 - val_loss: 0.0076 - val_accuracy: 0.9089
# Epoch 22/50
# 818880/818880 [==============================] - 54s 66us/step - loss: 0.0071 - accuracy: 0.9116 - val_loss: 0.0075 - val_accuracy: 0.9114
# Epoch 23/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0069 - accuracy: 0.9130 - val_loss: 0.0073 - val_accuracy: 0.9126
# Epoch 24/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0067 - accuracy: 0.9143 - val_loss: 0.0071 - val_accuracy: 0.9131
# Epoch 25/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0065 - accuracy: 0.9156 - val_loss: 0.0068 - val_accuracy: 0.9158
# Epoch 26/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0063 - accuracy: 0.9171 - val_loss: 0.0069 - val_accuracy: 0.9149
# Epoch 27/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0061 - accuracy: 0.9188 - val_loss: 0.0066 - val_accuracy: 0.9164
# Epoch 28/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0060 - accuracy: 0.9196 - val_loss: 0.0064 - val_accuracy: 0.9180
# Epoch 29/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0058 - accuracy: 0.9207 - val_loss: 0.0063 - val_accuracy: 0.9184
# Epoch 30/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0057 - accuracy: 0.9217 - val_loss: 0.0062 - val_accuracy: 0.9194
# Epoch 31/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0055 - accuracy: 0.9225 - val_loss: 0.0059 - val_accuracy: 0.9212
# Epoch 32/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0054 - accuracy: 0.9235 - val_loss: 0.0059 - val_accuracy: 0.9221
# Epoch 33/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0053 - accuracy: 0.9242 - val_loss: 0.0058 - val_accuracy: 0.9214
# Epoch 34/50
# 818880/818880 [==============================] - 53s 65us/step - loss: 0.0052 - accuracy: 0.9254 - val_loss: 0.0056 - val_accuracy: 0.9237
# Epoch 35/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0051 - accuracy: 0.9258 - val_loss: 0.0055 - val_accuracy: 0.9237
# Epoch 36/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0050 - accuracy: 0.9266 - val_loss: 0.0055 - val_accuracy: 0.9235
# Epoch 37/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0050 - accuracy: 0.9273 - val_loss: 0.0054 - val_accuracy: 0.9247
# Epoch 38/50
# 818880/818880 [==============================] - 51s 62us/step - loss: 0.0049 - accuracy: 0.9277 - val_loss: 0.0053 - val_accuracy: 0.9255
# Epoch 39/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0048 - accuracy: 0.9284 - val_loss: 0.0052 - val_accuracy: 0.9257
# Epoch 40/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0047 - accuracy: 0.9292 - val_loss: 0.0052 - val_accuracy: 0.9266
# Epoch 41/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0047 - accuracy: 0.9295 - val_loss: 0.0051 - val_accuracy: 0.9275
# Epoch 42/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0046 - accuracy: 0.9304 - val_loss: 0.0051 - val_accuracy: 0.9268
# Epoch 43/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0046 - accuracy: 0.9306 - val_loss: 0.0050 - val_accuracy: 0.9275
# Epoch 44/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0045 - accuracy: 0.9312 - val_loss: 0.0049 - val_accuracy: 0.9274
# Epoch 45/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0044 - accuracy: 0.9314 - val_loss: 0.0048 - val_accuracy: 0.9287
# Epoch 46/50
# 818880/818880 [==============================] - 53s 65us/step - loss: 0.0044 - accuracy: 0.9318 - val_loss: 0.0048 - val_accuracy: 0.9295
# Epoch 47/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0044 - accuracy: 0.9321 - val_loss: 0.0048 - val_accuracy: 0.9299
# Epoch 48/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0043 - accuracy: 0.9326 - val_loss: 0.0047 - val_accuracy: 0.9296
# Epoch 49/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0043 - accuracy: 0.9329 - val_loss: 0.0047 - val_accuracy: 0.9307
# Epoch 50/50
# 818880/818880 [==============================] - 50s 61us/step - loss: 0.0042 - accuracy: 0.9335 - val_loss: 0.0047 - val_accuracy: 0.9308

# %%
plt.semilogy(hist.history['loss'], color='b',label='train')
plt.semilogy(hist.history['val_loss'], color='g',label='validation')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()

# %%
Y_hat=model.predict(xtest)

# %%
plt.hist2d(ytest[:,0],Y_hat[:,0],bins=50,cmap=cm.RdYlBu)
plt.xlabel('Actual Parameter')
plt.ylabel('Predicted Parameter')
plt.plot(np.arange(-1,1,0.01),np.arange(-1,1,0.01))
plt.show()

key=np.random.randint(np.shape(ytest)[0],size=10000)
plt.scatter(ytest[key,0],Y_hat[key,0],s=1)
plt.xlabel('Actual Parameter')
plt.ylabel('Predicted Parameter')
plt.ylim(-0.5,0.5)
plt.xlim(-0.5,0.5)
plt.plot(np.arange(-1,1,0.01),np.arange(-1,1,0.01),c='r')
plt.show()

# %%
from matplotlib import cm

for i in range(15):
  plt.hist2d(Y[:,i],Y_hat[:,i],bins=50,cmap=cm.RdYlBu)
  plt.xlabel('Actual Parameter')
  plt.ylabel('Predicted Parameter')
  plt.plot(np.arange(-1,1,0.01),np.arange(-1,1,0.01))
  plt.show()

# %%
R2=[]
from sklearn.metrics import r2_score 
for i in range(15):
  R2.append(np.round(r2_score(Y[:,i], Y_hat[:,i]),3))
print(R2)
plt.plot(R2,marker='*')
# Out:
# [0.915, 0.915, 0.956, 0.925, 0.929, 0.821, 0.994, 0.993, 0.994, 0.994, 0.994, 0.995, 0.982, 0.987, 0.963]
