# %%
# !pip install -q tensorflow==2.1.0
# Out:
#      |████████████████████████████████| 421.8MB 41kB/s
#      |████████████████████████████████| 3.9MB 45.4MB/s
#      |████████████████████████████████| 450kB 45.2MB/s
#   Building wheel for gast (setup.py) ... done
# ERROR: tensorflow-probability 0.10.0rc0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.

# %%
# !pip install -q tensorflow-quantum
# Out:
#      |████████████████████████████████| 4.5MB 2.7MB/s
#      |████████████████████████████████| 1.2MB 30.8MB/s
#      |████████████████████████████████| 1.2MB 42.2MB/s
#      |████████████████████████████████| 5.3MB 39.6MB/s
#      |████████████████████████████████| 1.8MB 53.6MB/s
#   Building wheel for networkx (setup.py) ... done
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
import tensorflow as tf
import tensorflow_quantum as tfq

import cirq
import sympy
import numpy as np

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit

# %%
qubit = cirq.GridQubit(0, 0)

circuit1 = cirq.Circuit(cirq.X(qubit))
circuit2 = cirq.Circuit(cirq.H(qubit))

input_circuit_tensor = tfq.convert_to_tensor([circuit1, circuit2])

y_circuit = cirq.Circuit(cirq.Y(qubit))

y_appender = tfq.layers.AddCircuit()

output_circuit_tensor = y_appender(input_circuit_tensor, append=y_circuit)

# %%
print(tfq.from_tensor(input_circuit_tensor))
# Out:
# [cirq.Circuit([
#     cirq.Moment(operations=[
#         cirq.X.on(cirq.GridQubit(0, 0)),
#     ]),
# ])
#  cirq.Circuit([
#     cirq.Moment(operations=[
#         cirq.H.on(cirq.GridQubit(0, 0)),
#     ]),
# ])]

# %%
print(tfq.from_tensor(output_circuit_tensor))
# Out:
# [cirq.Circuit([
#     cirq.Moment(operations=[
#         cirq.X.on(cirq.GridQubit(0, 0)),
#     ]),
#     cirq.Moment(operations=[
#         cirq.Y.on(cirq.GridQubit(0, 0)),
#     ]),
# ])
#  cirq.Circuit([
#     cirq.Moment(operations=[
#         cirq.H.on(cirq.GridQubit(0, 0)),
#     ]),
#     cirq.Moment(operations=[
#         cirq.Y.on(cirq.GridQubit(0, 0)),
#     ]),
# ])]

# %%
def generate_data(qubits):
    n_rounds = 20  
    excitations = []
    labels = []
    for n in range(n_rounds):
        for bit in qubits:
            rng = np.random.uniform(-np.pi, np.pi)
            excitations.append(cirq.Circuit(cirq.rx(rng)(bit)))
            labels.append(1 if (-np.pi / 2) <= rng <= (np.pi / 2) else -1)

    split_ind = int(len(excitations) * 0.7)
    train_excitations = excitations[:split_ind]
    test_excitations = excitations[split_ind:]

    train_labels = labels[:split_ind]
    test_labels = labels[split_ind:]

    return tfq.convert_to_tensor(train_excitations), np.array(train_labels), \
        tfq.convert_to_tensor(test_excitations), np.array(test_labels)

# %%
sample_points, sample_labels, _, __ = generate_data(cirq.GridQubit.rect(1, 4))
print('Input:', tfq.from_tensor(sample_points)[0], 'Output:', sample_labels[0])
print('Input:', tfq.from_tensor(sample_points)[1], 'Output:', sample_labels[1])
# Out:
# Input: (0, 0): ───Rx(-0.706π)─── Output: -1
# Input: (0, 1): ───Rx(0.798π)─── Output: -1

# %%
def cluster_state_circuit(bits):
    circuit = cirq.Circuit()
    circuit.append(cirq.H.on_each(bits))
    for this_bit, next_bit in zip(bits, bits[1:] + [bits[0]]):
        circuit.append(cirq.CZ(this_bit, next_bit))
    return circuit

# %%
SVGCircuit(cluster_state_circuit(cirq.GridQubit.rect(1, 4)))
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
def one_qubit_unitary(bit, symbols):
    return cirq.Circuit(
        cirq.X(bit)**symbols[0],
        cirq.Y(bit)**symbols[1],
        cirq.Z(bit)**symbols[2])


def two_qubit_unitary(bits, symbols):
    circuit = cirq.Circuit()
    circuit += one_qubit_unitary(bits[0], symbols[0:3])
    circuit += one_qubit_unitary(bits[1], symbols[3:6])
    circuit += [cirq.ZZ(*bits)**symbols[7]]
    circuit += [cirq.YY(*bits)**symbols[8]]
    circuit += [cirq.XX(*bits)**symbols[9]]
    circuit += one_qubit_unitary(bits[0], symbols[9:12])
    circuit += one_qubit_unitary(bits[1], symbols[12:])
    return circuit


def two_qubit_pool(source_qubit, sink_qubit, symbols):
    pool_circuit = cirq.Circuit()
    sink_basis_selector = one_qubit_unitary(sink_qubit, symbols[0:3])
    source_basis_selector = one_qubit_unitary(source_qubit, symbols[3:6])
    pool_circuit.append(sink_basis_selector)
    pool_circuit.append(source_basis_selector)
    pool_circuit.append(cirq.CNOT(control=source_qubit, target=sink_qubit))
    pool_circuit.append(sink_basis_selector**-1)
    return pool_circuit

# %%
SVGCircuit(one_qubit_unitary(cirq.GridQubit(0, 0), sympy.symbols('x0:3')))

# %%
SVGCircuit(two_qubit_unitary(cirq.GridQubit.rect(1, 2), sympy.symbols('x0:15')))

# %%
SVGCircuit(two_qubit_pool(*cirq.GridQubit.rect(1, 2), sympy.symbols('x0:6')))

# %%
def quantum_conv_circuit(bits, symbols):
    circuit = cirq.Circuit()
    for first, second in zip(bits[0::2], bits[1::2]):
        circuit += two_qubit_unitary([first, second], symbols)
    for first, second in zip(bits[1::2], bits[2::2] + [bits[0]]):
        circuit += two_qubit_unitary([first, second], symbols)
    return circuit

# %%
SVGCircuit(
    quantum_conv_circuit(cirq.GridQubit.rect(1, 8), sympy.symbols('x0:15')))

# %%
def quantum_pool_circuit(source_bits, sink_bits, symbols):
    circuit = cirq.Circuit()
    for source, sink in zip(source_bits, sink_bits):
        circuit += two_qubit_pool(source, sink, symbols)
    return circuit

# %%
test_bits = cirq.GridQubit.rect(1, 8)

SVGCircuit(
    quantum_pool_circuit(test_bits[:4], test_bits[4:], sympy.symbols('x0:6')))

# %%
def create_model_circuit(qubits):
    model_circuit = cirq.Circuit()
    symbols = sympy.symbols('qconv0:63')

    model_circuit += quantum_conv_circuit(qubits, symbols[0:15])
    model_circuit += quantum_pool_circuit(qubits[:4], qubits[4:],
                                          symbols[15:21])
    model_circuit += quantum_conv_circuit(qubits[4:], symbols[21:36])
    model_circuit += quantum_pool_circuit(qubits[4:6], qubits[6:],
                                          symbols[36:42])
    model_circuit += quantum_conv_circuit(qubits[6:], symbols[42:57])
    model_circuit += quantum_pool_circuit([qubits[6]], [qubits[7]],symbols[57:63])
    return model_circuit

cluster_state_bits = cirq.GridQubit.rect(1, 8)
readout_operators = cirq.Z(cluster_state_bits[-1])

excitation_input = tf.keras.Input(shape=(), dtype=tf.dtypes.string)
cluster_state = tfq.layers.AddCircuit()(
    excitation_input, prepend=cluster_state_circuit(cluster_state_bits))

quantum_model = tfq.layers.PQC(create_model_circuit(cluster_state_bits),
                               readout_operators)(cluster_state)

qcnn_model = tf.keras.Model(inputs=[excitation_input], outputs=[quantum_model])

tf.keras.utils.plot_model(qcnn_model,
                          show_shapes=True,
                          show_layer_names=False,
                          dpi=70)

# %%
qubits=cirq.GridQubit.rect(1, 8)
circuit=create_model_circuit(qubits)
SVGCircuit(circuit)

# %%
train_excitations, train_labels, test_excitations, test_labels = generate_data(
    cluster_state_bits)

@tf.function
def custom_accuracy(y_true, y_pred):
    y_true = tf.squeeze(y_true)
    y_pred = tf.map_fn(lambda x: 1.0 if x >= 0 else -1.0, y_pred)
    return tf.keras.backend.mean(tf.keras.backend.equal(y_true, y_pred))


qcnn_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
                   loss=tf.losses.mse,
                   metrics=[custom_accuracy])

print(qcnn_model.summary())

history = qcnn_model.fit(x=train_excitations,
                         y=train_labels,
                         batch_size=16,
                         epochs=25,
                         verbose=1,
                         validation_data=(test_excitations, test_labels))
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None,)]                 0
# _________________________________________________________________
# add_circuit_22 (AddCircuit)  (None,)                   0
# _________________________________________________________________
# pqc_12 (PQC)                 (None, 1)                 60
# =================================================================
# Total params: 60
# Trainable params: 60
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 112 samples, validate on 48 samples
# Epoch 1/25
# 112/112 [==============================] - 11s 103ms/sample - loss: 0.9020 - custom_accuracy: 0.7143 - val_loss: 0.7853 - val_custom_accuracy: 0.8958
# Epoch 2/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.8031 - custom_accuracy: 0.8036 - val_loss: 0.7523 - val_custom_accuracy: 0.8958
# Epoch 3/25
# 112/112 [==============================] - 11s 103ms/sample - loss: 0.7516 - custom_accuracy: 0.8571 - val_loss: 0.7278 - val_custom_accuracy: 0.8542
# Epoch 4/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.7338 - custom_accuracy: 0.8393 - val_loss: 0.6904 - val_custom_accuracy: 0.8542
# Epoch 5/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.7213 - custom_accuracy: 0.8750 - val_loss: 0.6740 - val_custom_accuracy: 0.9167
# Epoch 6/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.6924 - custom_accuracy: 0.9018 - val_loss: 0.6556 - val_custom_accuracy: 0.9583
# Epoch 7/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.6307 - custom_accuracy: 0.9464 - val_loss: 0.5453 - val_custom_accuracy: 0.9375
# Epoch 8/25
# 112/112 [==============================] - 11s 97ms/sample - loss: 0.4813 - custom_accuracy: 0.9375 - val_loss: 0.3893 - val_custom_accuracy: 1.0000
# Epoch 9/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.3498 - custom_accuracy: 0.9643 - val_loss: 0.3143 - val_custom_accuracy: 1.0000
# Epoch 10/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.3040 - custom_accuracy: 0.9643 - val_loss: 0.3175 - val_custom_accuracy: 0.9583
# Epoch 11/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.3061 - custom_accuracy: 0.9732 - val_loss: 0.2735 - val_custom_accuracy: 1.0000
# Epoch 12/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2848 - custom_accuracy: 0.9821 - val_loss: 0.2753 - val_custom_accuracy: 1.0000
# Epoch 13/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2740 - custom_accuracy: 0.9643 - val_loss: 0.2567 - val_custom_accuracy: 1.0000
# Epoch 14/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2726 - custom_accuracy: 0.9643 - val_loss: 0.2589 - val_custom_accuracy: 1.0000
# Epoch 15/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2650 - custom_accuracy: 0.9643 - val_loss: 0.2808 - val_custom_accuracy: 1.0000
# Epoch 16/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2666 - custom_accuracy: 0.9732 - val_loss: 0.2662 - val_custom_accuracy: 1.0000
# Epoch 17/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2722 - custom_accuracy: 0.9732 - val_loss: 0.2609 - val_custom_accuracy: 1.0000
# Epoch 18/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2691 - custom_accuracy: 0.9732 - val_loss: 0.2531 - val_custom_accuracy: 1.0000
# Epoch 19/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2668 - custom_accuracy: 0.9732 - val_loss: 0.2660 - val_custom_accuracy: 1.0000
# Epoch 20/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2625 - custom_accuracy: 0.9911 - val_loss: 0.2525 - val_custom_accuracy: 1.0000
# Epoch 21/25
# 112/112 [==============================] - 11s 97ms/sample - loss: 0.2658 - custom_accuracy: 0.9732 - val_loss: 0.2759 - val_custom_accuracy: 1.0000
# Epoch 22/25
# 112/112 [==============================] - 11s 97ms/sample - loss: 0.2762 - custom_accuracy: 0.9643 - val_loss: 0.2943 - val_custom_accuracy: 0.9583
# Epoch 23/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2783 - custom_accuracy: 0.9911 - val_loss: 0.2719 - val_custom_accuracy: 1.0000
# Epoch 24/25
# 112/112 [==============================] - 11s 96ms/sample - loss: 0.2901 - custom_accuracy: 0.9643 - val_loss: 0.3262 - val_custom_accuracy: 0.9375
# Epoch 25/25
# 112/112 [==============================] - 11s 97ms/sample - loss: 0.2802 - custom_accuracy: 1.0000 - val_loss: 0.2679 - val_custom_accuracy: 1.0000

# %%
plt.plot(history.history['loss'][1:], label='Training')
plt.plot(history.history['val_loss'][1:], label='Validation')
plt.title('Training a Quantum CNN to Detect Excited Cluster States')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
readouts = [cirq.Z(bit) for bit in cluster_state_bits[4:]]


def multi_readout_model_circuit(qubits):
    model_circuit = cirq.Circuit()
    symbols = sympy.symbols('qconv0:21')
    model_circuit += quantum_conv_circuit(qubits, symbols[0:15])
    model_circuit += quantum_pool_circuit(qubits[:4], qubits[4:],
                                          symbols[15:21])
    return model_circuit

excitation_input_dual = tf.keras.Input(shape=(), dtype=tf.dtypes.string)

cluster_state_dual = tfq.layers.AddCircuit()(
    excitation_input_dual, prepend=cluster_state_circuit(cluster_state_bits))

quantum_model_dual = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_dual)

d1_dual = tf.keras.layers.Dense(8)(quantum_model_dual)

d2_dual = tf.keras.layers.Dense(1)(d1_dual)

hybrid_model = tf.keras.Model(inputs=[excitation_input_dual], outputs=[d2_dual])

tf.keras.utils.plot_model(hybrid_model,
                          show_shapes=True,
                          show_layer_names=False,
                          dpi=70)

print(hybrid_model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None,)]                 0
# _________________________________________________________________
# add_circuit_9 (AddCircuit)   (None,)                   0
# _________________________________________________________________
# pqc_5 (PQC)                  (None, 4)                 20
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 40
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 69
# Trainable params: 69
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hybrid_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
                     loss=tf.losses.mse,
                     metrics=[custom_accuracy])

hybrid_history = hybrid_model.fit(x=train_excitations,
                                  y=train_labels,
                                  batch_size=16,
                                  epochs=25,
                                  verbose=1,
                                  validation_data=(test_excitations,
                                                   test_labels))
# Out:
# Train on 112 samples, validate on 48 samples
# Epoch 1/25
# 112/112 [==============================] - 3s 30ms/sample - loss: 1.0046 - custom_accuracy: 0.4643 - val_loss: 0.9036 - val_custom_accuracy: 0.5208
# Epoch 2/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.7646 - custom_accuracy: 0.7679 - val_loss: 0.4775 - val_custom_accuracy: 0.8333
# Epoch 3/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.3249 - custom_accuracy: 0.9107 - val_loss: 0.2492 - val_custom_accuracy: 0.9375
# Epoch 4/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2587 - custom_accuracy: 0.9375 - val_loss: 0.2681 - val_custom_accuracy: 0.9792
# Epoch 5/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2608 - custom_accuracy: 0.9375 - val_loss: 0.2971 - val_custom_accuracy: 0.9583
# Epoch 6/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2916 - custom_accuracy: 0.9375 - val_loss: 0.2597 - val_custom_accuracy: 0.9167
# Epoch 7/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2587 - custom_accuracy: 0.9286 - val_loss: 0.2579 - val_custom_accuracy: 0.9375
# Epoch 8/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2386 - custom_accuracy: 0.9464 - val_loss: 0.2158 - val_custom_accuracy: 0.9792
# Epoch 9/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2331 - custom_accuracy: 0.9464 - val_loss: 0.2125 - val_custom_accuracy: 1.0000
# Epoch 10/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2344 - custom_accuracy: 0.9643 - val_loss: 0.2201 - val_custom_accuracy: 0.9375
# Epoch 11/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2198 - custom_accuracy: 0.9821 - val_loss: 0.2287 - val_custom_accuracy: 0.9792
# Epoch 12/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2232 - custom_accuracy: 0.9464 - val_loss: 0.2251 - val_custom_accuracy: 0.9792
# Epoch 13/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2255 - custom_accuracy: 0.9464 - val_loss: 0.2280 - val_custom_accuracy: 0.9375
# Epoch 14/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2262 - custom_accuracy: 0.9643 - val_loss: 0.2094 - val_custom_accuracy: 0.9792
# Epoch 15/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2329 - custom_accuracy: 0.9643 - val_loss: 0.2654 - val_custom_accuracy: 0.9583
# Epoch 16/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2280 - custom_accuracy: 0.9464 - val_loss: 0.2238 - val_custom_accuracy: 0.9792
# Epoch 17/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2071 - custom_accuracy: 0.9732 - val_loss: 0.2284 - val_custom_accuracy: 0.9792
# Epoch 18/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2209 - custom_accuracy: 0.9554 - val_loss: 0.2380 - val_custom_accuracy: 1.0000
# Epoch 19/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2534 - custom_accuracy: 0.9643 - val_loss: 0.2207 - val_custom_accuracy: 0.9583
# Epoch 20/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2289 - custom_accuracy: 0.9375 - val_loss: 0.2682 - val_custom_accuracy: 0.9375
# Epoch 21/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2576 - custom_accuracy: 0.9286 - val_loss: 0.2178 - val_custom_accuracy: 0.9375
# Epoch 22/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2321 - custom_accuracy: 0.9554 - val_loss: 0.2718 - val_custom_accuracy: 0.9792
# Epoch 23/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2232 - custom_accuracy: 0.9643 - val_loss: 0.2179 - val_custom_accuracy: 0.9583
# Epoch 24/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2181 - custom_accuracy: 0.9554 - val_loss: 0.2194 - val_custom_accuracy: 1.0000
# Epoch 25/25
# 112/112 [==============================] - 3s 23ms/sample - loss: 0.2249 - custom_accuracy: 0.9643 - val_loss: 0.2404 - val_custom_accuracy: 0.9792

# %%
plt.plot(history.history['val_custom_accuracy'], label='QCNN')
plt.plot(hybrid_history.history['val_custom_accuracy'], label='Hybrid CNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()

# %%
excitation_input_multi = tf.keras.Input(shape=(), dtype=tf.dtypes.string)

cluster_state_multi = tfq.layers.AddCircuit()(
    excitation_input_multi, prepend=cluster_state_circuit(cluster_state_bits))

quantum_model_multi1 = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_multi)

quantum_model_multi2 = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_multi)

quantum_model_multi3 = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_multi)

concat_out = tf.keras.layers.concatenate(
    [quantum_model_multi1, quantum_model_multi2, quantum_model_multi3])

dense_1 = tf.keras.layers.Dense(8)(concat_out)

dense_2 = tf.keras.layers.Dense(1)(dense_1)

multi_qconv_model = tf.keras.Model(inputs=[excitation_input_multi],
                                   outputs=[dense_2])


print(multi_qconv_model.summary())

tf.keras.utils.plot_model(multi_qconv_model,
                          show_shapes=True,
                          show_layer_names=True,
                          dpi=70)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None,)]            0
# __________________________________________________________________________________________________
# add_circuit_13 (AddCircuit)     (None,)              0           input_6[0][0]
# __________________________________________________________________________________________________
# pqc_7 (PQC)                     (None, 4)            20          add_circuit_13[0][0]
# __________________________________________________________________________________________________
# pqc_8 (PQC)                     (None, 4)            20          add_circuit_13[0][0]
# __________________________________________________________________________________________________
# pqc_9 (PQC)                     (None, 4)            20          add_circuit_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           pqc_7[0][0]
#                                                                  pqc_8[0][0]
#                                                                  pqc_9[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 8)            104         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            9           dense_6[0][0]
# ==================================================================================================
# Total params: 173
# Trainable params: 173
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
multi_qconv_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
    loss=tf.losses.mse,
    metrics=[custom_accuracy])

multi_qconv_history = multi_qconv_model.fit(x=train_excitations,
                                            y=train_labels,
                                            batch_size=16,
                                            epochs=25,
                                            verbose=1,
                                            validation_data=(test_excitations,
                                                             test_labels))
# Out:
# Train on 112 samples, validate on 48 samples
# Epoch 1/25
# 112/112 [==============================] - 9s 81ms/sample - loss: 0.5913 - custom_accuracy: 0.8125 - val_loss: 0.2405 - val_custom_accuracy: 0.9792
# Epoch 2/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2745 - custom_accuracy: 0.9554 - val_loss: 0.2752 - val_custom_accuracy: 0.9583
# Epoch 3/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2689 - custom_accuracy: 0.9464 - val_loss: 0.2441 - val_custom_accuracy: 0.9792
# Epoch 4/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2398 - custom_accuracy: 0.9911 - val_loss: 0.2443 - val_custom_accuracy: 0.9583
# Epoch 5/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2594 - custom_accuracy: 0.9554 - val_loss: 0.2669 - val_custom_accuracy: 0.9583
# Epoch 6/25
# 112/112 [==============================] - 7s 67ms/sample - loss: 0.2339 - custom_accuracy: 0.9821 - val_loss: 0.2603 - val_custom_accuracy: 0.9792
# Epoch 7/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2275 - custom_accuracy: 0.9554 - val_loss: 0.2111 - val_custom_accuracy: 0.9792
# Epoch 8/25
# 112/112 [==============================] - 7s 67ms/sample - loss: 0.2128 - custom_accuracy: 0.9643 - val_loss: 0.2513 - val_custom_accuracy: 0.9583
# Epoch 9/25
# 112/112 [==============================] - 8s 75ms/sample - loss: 0.2076 - custom_accuracy: 0.9554 - val_loss: 0.2301 - val_custom_accuracy: 0.9583
# Epoch 10/25
# 112/112 [==============================] - 7s 67ms/sample - loss: 0.2174 - custom_accuracy: 0.9821 - val_loss: 0.2537 - val_custom_accuracy: 0.9792
# Epoch 11/25
# 112/112 [==============================] - 7s 67ms/sample - loss: 0.2168 - custom_accuracy: 0.9554 - val_loss: 0.2400 - val_custom_accuracy: 0.9792
# Epoch 12/25
# 112/112 [==============================] - 7s 67ms/sample - loss: 0.2074 - custom_accuracy: 0.9911 - val_loss: 0.2111 - val_custom_accuracy: 0.9583
# Epoch 13/25
# 112/112 [==============================] - 7s 67ms/sample - loss: 0.2181 - custom_accuracy: 0.9732 - val_loss: 0.2207 - val_custom_accuracy: 0.9583
# Epoch 14/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.1956 - custom_accuracy: 0.9643 - val_loss: 0.2235 - val_custom_accuracy: 0.9792
# Epoch 15/25
# 112/112 [==============================] - 8s 67ms/sample - loss: 0.2002 - custom_accuracy: 0.9821 - val_loss: 0.2271 - val_custom_accuracy: 0.9583
# Epoch 16/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2002 - custom_accuracy: 0.9821 - val_loss: 0.2323 - val_custom_accuracy: 0.9792
# Epoch 17/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.1981 - custom_accuracy: 0.9554 - val_loss: 0.2207 - val_custom_accuracy: 0.9583
# Epoch 18/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2067 - custom_accuracy: 0.9643 - val_loss: 0.2280 - val_custom_accuracy: 0.9792
# Epoch 19/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2078 - custom_accuracy: 0.9643 - val_loss: 0.2268 - val_custom_accuracy: 0.9583
# Epoch 20/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2339 - custom_accuracy: 0.9464 - val_loss: 0.2354 - val_custom_accuracy: 0.9583
# Epoch 21/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2239 - custom_accuracy: 0.9643 - val_loss: 0.2161 - val_custom_accuracy: 0.9583
# Epoch 22/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2132 - custom_accuracy: 0.9643 - val_loss: 0.2258 - val_custom_accuracy: 0.9792
# Epoch 23/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.2021 - custom_accuracy: 0.9821 - val_loss: 0.2235 - val_custom_accuracy: 0.9792
# Epoch 24/25
# 112/112 [==============================] - 7s 66ms/sample - loss: 0.1973 - custom_accuracy: 0.9821 - val_loss: 0.2203 - val_custom_accuracy: 0.9792
# Epoch 25/25
# 112/112 [==============================] - 7s 67ms/sample - loss: 0.2288 - custom_accuracy: 0.9554 - val_loss: 0.2043 - val_custom_accuracy: 0.9792

# %%
plt.plot(history.history['val_custom_accuracy'][:25], label='QCNN')
plt.plot(hybrid_history.history['val_custom_accuracy'][:25], label='Hybrid CNN')
plt.plot(multi_qconv_history.history['val_custom_accuracy'][:25],
         label='Hybrid CNN \n Multiple Quantum Filters')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()
